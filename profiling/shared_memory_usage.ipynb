# %%
import math
import numpy as np

# %%
bm = 128
bn = 128
bk = 64
num_buffer = 2

# %%
a_smem = bm * (bk / 2) * 2
b_smem = bk * bn * 2
c_smem = bm * bn * 2
smem_usage = (a_smem + b_smem) * num_buffer + c_smem
smem_usage
# Out:
# 131072.0
